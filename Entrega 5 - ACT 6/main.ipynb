# %%
import pandas as pd
lagos = pd.read_csv('lagos_arg.csv')

# %%
import folium
def generate_map():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a>'
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</>'
        )
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-40.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

sup_color = {
    "grande":"green",
    "medio":"lightblue",
    "chico":"red",
}
def add_marker(row):
    folium.Marker(
        [row['Latitud en GD'], row['Longitud en GD']],
        popup=row['Nombre'],
        icon=folium.Icon(color= sup_color.get(row['Sup Tamaño']))
        ).add_to(mapa)
mapa = generate_map()

lagos.apply(add_marker, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e448598b90b66911827fcb7ea52350e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e448598b90b66911827fcb7ea52350e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e448598b90b66911827fcb7ea52350e = L.map(
#                 &quot;map_4e448598b90b66911827fcb7ea52350e&quot;,
#                 {
#                     center: [-40.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;es&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_4e448598b90b66911827fcb7ea52350e);
#
#
#
#
#
#             var tile_layer_0ff7231c94efc2cb7866a011abf5fbb6 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003econtributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0ff7231c94efc2cb7866a011abf5fbb6.addTo(map_4e448598b90b66911827fcb7ea52350e);
#
#
#             var marker_acc0207f3c43597b60fdf4e613c03e24 = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {}
#             ).addTo(map_4e448598b90b66911827fcb7ea52350e);
#
#
#             var icon_715c661565a7c5a1ded9e33c75341f8b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_acc0207f3c43597b60fdf4e613c03e24.setIcon(icon_715c661565a7c5a1ded9e33c75341f8b);
#
#
#         var popup_a48b86d2bad9886fcf61b9a84c9fe355 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c2efab41b8317bddcc3a530e64f9179 = $(`&lt;div id=&quot;html_4c2efab41b8317bddcc3a530e64f9179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_a48b86d2bad9886fcf61b9a84c9fe355.setContent(html_4c2efab41b8317bddcc3a530e64f9179);
#
#
#
#         marker_acc0207f3c43597b60fdf4e613c03e24.bindPopup(popup_a48b86d2bad9886fcf61b9a84c9fe355)
#         ;
#
#
#
#
#             var marker_307bdda9e48abaf88d9d462897d9e4e6 = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {}
#             ).addTo(map_4e448598b90b66911827fcb7ea52350e);
#
#
#             var icon_48e91ca45ab8076ebafb997b944404ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_307bdda9e48abaf88d9d462897d9e4e6.setIcon(icon_48e91ca45ab8076ebafb997b944404ef);
#
#
#         var popup_f4cf5ce33ef52142825138f43ef0af07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48e0c7ccc3d6f7af5ffc7a1050282e52 = $(`&lt;div id=&quot;html_48e0c7ccc3d6f7af5ffc7a1050282e52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_f4cf5ce33ef52142825138f43ef0af07.setContent(html_48e0c7ccc3d6f7af5ffc7a1050282e52);
#
#
#
#         marker_307bdda9e48abaf88d9d462897d9e4e6.bindPopup(popup_f4cf5ce33ef52142825138f43ef0af07)
#         ;
#
#
#
#
#             var marker_f1ae0d22a243c36528a6a3fd8cbb6945 = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {}
#             ).addTo(map_4e448598b90b66911827fcb7ea52350e);
#
#
#             var icon_074d019fc3ed2df820e4df96a5f1ee91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f1ae0d22a243c36528a6a3fd8cbb6945.setIcon(icon_074d019fc3ed2df820e4df96a5f1ee91);
#
#
#         var popup_a749b34862418c7b45769064b88a3f00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a164cc82f09fc4b58496cdd33f477ebd = $(`&lt;div id=&quot;html_a164cc82f09fc4b58496cdd33f477ebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_a749b34862418c7b45769064b88a3f00.setContent(html_a164cc82f09fc4b58496cdd33f477ebd);
#
#
#
#         marker_f1ae0d22a243c36528a6a3fd8cbb6945.bindPopup(popup_a749b34862418c7b45769064b88a3f00)
#         ;
#
#
#
#
#             var marker_487a529e35381ec06d936ee61aa905f4 = L.marker(
#                 [-45.414722222222224, -69.19777777777779],
