# %%
import pandas as pd
lagos = pd.read_csv('lagos_arg.csv')

# %%
import folium
def generate_map():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a>'
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</>'
        )
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-40.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

sup_color = {
    "grande":"green",
    "medio":"lightblue",
    "chico":"red",
}

def get_color(data):
    match data:
        case "grande":
            return "green"
        case "medio":
            return "lightblue"
        case "chico":
            return "red"
    
def add_marker(row):
    folium.Marker(
        [row['Latitud en GD'], row['Longitud en GD']],
        popup=row['Nombre'],
        icon = folium.Icon(color='green' if row['Sup Tamaño'] == 'grande' else ('lightblue' if row['Sup Tamaño'] == 'medio' else 'red'))
        #icon=folium.Icon(color= get_color(row['Sup Tamaño']))
        #icon=folium.Icon(color= sup_color.get(row['Sup Tamaño']))
        ).add_to(mapa)
mapa = generate_map()

lagos.apply(add_marker, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
